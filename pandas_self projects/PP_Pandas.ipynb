# %%
import pandas as pd
f_csv = pd.read_csv('pokemon_data.csv')
f_csv.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
f_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
f_txt = pd.read_csv('pokemon_data.txt',delimiter='\t')
f_txt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
print(f_txt.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
print(f_txt['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
print(f_txt[['Name','HP','Generation']])
f_txt[['Name','HP','Generation']]
# Out:
#                       Name  HP  Generation
# 0                Bulbasaur  45           1
# 1                  Ivysaur  60           1
# 2                 Venusaur  80           1
# 3    VenusaurMega Venusaur  80           1
# 4               Charmander  39           1
# ..                     ...  ..         ...
# 795                Diancie  50           6
# 796    DiancieMega Diancie  50           6
# 797    HoopaHoopa Confined  80           6
# 798     HoopaHoopa Unbound  80           6
# 799              Volcanion  80           6
#
# [800 rows x 3 columns]
#                       Name  HP  Generation
# 0                Bulbasaur  45           1
# 1                  Ivysaur  60           1
# 2                 Venusaur  80           1
# 3    VenusaurMega Venusaur  80           1
# 4               Charmander  39           1
# ..                     ...  ..         ...
# 795                Diancie  50           6
# 796    DiancieMega Diancie  50           6
# ...

# %% [raw]
# Read each Row

# %%
print(f_txt.iloc[1:4])
print(f_txt.iloc[0:4])
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# ...

# %% [markdown]
# iterated by each row column

# %%
for index, row in f_txt.iterrows():
    print(index, row['Name'])
# Out:
# 0 Bulbasaur
# 1 Ivysaur
# 2 Venusaur
# 3 VenusaurMega Venusaur
# 4 Charmander
# 5 Charmeleon
# 6 Charizard
# 7 CharizardMega Charizard X
# 8 CharizardMega Charizard Y
# 9 Squirtle
# 10 Wartortle
# 11 Blastoise
# 12 BlastoiseMega Blastoise
# 13 Caterpie
# 14 Metapod
# 15 Butterfree
# 16 Weedle
# 17 Kakuna
# 18 Beedrill
# 19 BeedrillMega Beedrill
# 20 Pidgey
# 21 Pidgeotto
# 22 Pidgeot
# 23 PidgeotMega Pidgeot
# 24 Rattata
# 25 Raticate
# 26 Spearow
# 27 Fearow
# 28 Ekans
# 29 Arbok
# 30 Pikachu
# 31 Raichu
# 32 Sandshrew
# 33 Sandslash
# 34 Nidoran (Female)
# 35 Nidorina
# 36 Nidoqueen
# 37 Nidoran (Male)
# 38 Nidorino
# 39 Nidoking
# 40 Clefairy
# 41 Clefable
# 42 Vulpix
# 43 Ninetales
# 44 Jigglypuff
# 45 Wigglytuff
# 46 Zubat
# 47 Golbat
# 48 Oddish
# 49 Gloom
# 50 Vileplume
# 51 Paras
# 52 Parasect
# 53 Venonat
# 54 Venomoth
# 55 Diglett
# 56 Dugtrio
# 57 Meowth
# 58 Persian
# 59 Psyduck
# 60 Golduck
# 61 Mankey
# 62 Primeape
# 63 Growlithe
# 64 Arcanine
# 65 Poliwag
# ...

# %% [markdown]
# To select a specific nameed data sets(sorting/filtering)

# %%
f_txt.loc[f_txt['Type 1'] == "Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %%
f_txt.loc[f_txt['Type 2'] == "Dragon"]
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 7      6  CharizardMega Charizard X      Fire  Dragon   78     130      111
# 196  181      AmpharosMega Ampharos  Electric  Dragon   90      95      105
# 249  230                    Kingdra     Water  Dragon   75      95       95
# 275  254      SceptileMega Sceptile     Grass  Dragon   70     110       75
# 360  329                    Vibrava    Ground  Dragon   50      70       50
# 361  330                     Flygon    Ground  Dragon   80     100       80
# 540  483                     Dialga     Steel  Dragon  100     120      120
# 541  484                     Palkia     Water  Dragon   90     120      100
# 544  487      GiratinaAltered Forme     Ghost  Dragon  150     100      120
# 545  487       GiratinaOrigin Forme     Ghost  Dragon  150     120      100
# 694  633                      Deino      Dark  Dragon   52      65       50
# ...

# %% [markdown]
# Sorting/Describing Data

# %%
f_txt.sort_values(['Type 1','HP'], ascending=True)
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %%
f_txt.sort_values(['Type 1','HP'], ascending=[1,0])
# Out:
#        #                     Name Type 1    Type 2  HP  Attack  Defense  \
# 520  469                  Yanmega    Bug    Flying  86      76       86
# 698  637                Volcarona    Bug      Fire  85      60       65
# 231  214                Heracross    Bug  Fighting  80     125       75
# 232  214  HeracrossMega Heracross    Bug  Fighting  80     185      115
# 678  617                 Accelgor    Bug       NaN  80      70       40
# ..   ...                      ...    ...       ...  ..     ...      ...
# 106   98                   Krabby  Water       NaN  30     105       90
# 125  116                   Horsea  Water       NaN  30      40       70
# 129  120                   Staryu  Water       NaN  30      45       55
# 139  129                 Magikarp  Water       NaN  20      10       55
# 381  349                   Feebas  Water       NaN  20      15       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
f_txt.sort_values('Name')
# Out:
#        #                     Name   Type 1  Type 2   HP  Attack  Defense  \
# 510  460                Abomasnow    Grass     Ice   90      92       75
# 511  460  AbomasnowMega Abomasnow    Grass     Ice   90     132      105
# 68    63                     Abra  Psychic     NaN   25      20       15
# 392  359                    Absol     Dark     NaN   65     130       60
# 393  359          AbsolMega Absol     Dark     NaN   65     150       60
# ..   ...                      ...      ...     ...  ...     ...      ...
# 632  571                  Zoroark     Dark     NaN   60     105       60
# 631  570                    Zorua     Dark     NaN   40      65       40
# 46    41                    Zubat   Poison  Flying   40      45       35
# 695  634                 Zweilous     Dark  Dragon   72      85       70
# 794  718         Zygarde50% Forme   Dragon  Ground  108     100      121
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Adding a column with data

# %%
Total = f_txt['Total'] = f_txt['HP']+f_txt['Attack']+f_txt['Defense']+f_txt['Sp. Atk']+f_txt['Sp. Def']+f_txt['Speed']

# %%
f_txt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
f_txt['Total'] = f_txt.iloc[:,4:10].sum(axis=1)

# %%
f_txt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %% [markdown]
# Dropping a column

# %%
f_txt = f_txt.drop(columns=['Total'])

# %%
f_txt.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# Rearrange the column in the sheet

# %%
colm = list(f_txt.columns)
f_txt = f_txt[colm[0:4]+[colm[-1]]+colm[4:12]]
f_txt.head()
# Out:
#    #                   Name Type 1  Type 2  Legendary  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison      False  45      49       49
# 1  2                Ivysaur  Grass  Poison      False  60      62       63
# 2  3               Venusaur  Grass  Poison      False  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison      False  80     100      123
# 4  4             Charmander   Fire     NaN      False  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Saving the data in a file

# %%
f_txt.head()
# Out:
#    #                   Name Type 1  Type 2  Legendary  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison      False  45      49       49
# 1  2                Ivysaur  Grass  Poison      False  60      62       63
# 2  3               Venusaur  Grass  Poison      False  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison      False  80     100      123
# 4  4             Charmander   Fire     NaN      False  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
#from openpyxl import Workbook
#f_txt.to_csv('Modified.csv', index=False)
#f_txt.to_excel('Modified.xlsx', index=False)
f_txt.to_excel('Modified.xlsx', index=False)

# %% [markdown]
# Advanced

# %% [markdown]
# Filtering the data

# %%
f_txt.loc[f_txt['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass    Poison      False   45      49
# 1      2                Ivysaur  Grass    Poison      False   60      62
# 2      3               Venusaur  Grass    Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass    Poison      False   80     100
# 48    43                 Oddish  Grass    Poison      False   45      50
# ..   ...                    ...    ...       ...        ...  ...     ...
# 718  650                Chespin  Grass       NaN      False   56      61
# 719  651              Quilladin  Grass       NaN      False   61      78
# 720  652             Chesnaught  Grass  Fighting      False   88     107
# 740  672                 Skiddo  Grass       NaN      False   66      65
# 741  673                 Gogoat  Grass       NaN      False  123     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
f_txt.loc[(f_txt['Type 1'] == 'Grass') & (f_txt['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False   45      49
# 1      2                Ivysaur  Grass  Poison      False   60      62
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 48    43                 Oddish  Grass  Poison      False   45      50
# 49    44                  Gloom  Grass  Poison      False   60      65
# 50    45              Vileplume  Grass  Poison      False   75      80
# 75    69             Bellsprout  Grass  Poison      False   50      75
# 76    70             Weepinbell  Grass  Poison      False   65      90
# 77    71             Victreebel  Grass  Poison      False   80     105
# 344  315                Roselia  Grass  Poison      False   50      60
# 451  406                  Budew  Grass  Poison      False   40      30
# ...

# %%
new_df = f_txt.loc[(f_txt['Type 1'] == 'Grass') & (f_txt['Type 2'] == 'Poison') & (f_txt['HP'] > 70)]

# %%
new_df
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 50    45              Vileplume  Grass  Poison      False   75      80
# 77    71             Victreebel  Grass  Poison      False   80     105
# 652  591              Amoonguss  Grass  Poison      False  114      85
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 2         83      100      100     80           1      False
# 3        123      122      120     80           1      False
# 50        85      110       90     50           1      False
# 77        65      100       70     70           1      False
# 652       70       85       80     30           5      False

# %%
"""""new_df = new_df.reset_index()
new_df.to_csv('Filtered.csv')
new_df"""

# %% [markdown]
# Filtering by name Mega

# %%
f_txt.loc[f_txt['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Legendary   HP  \
# 3      3      VenusaurMega Venusaur     Grass    Poison      False   80
# 7      6  CharizardMega Charizard X      Fire    Dragon      False   78
# 8      6  CharizardMega Charizard Y      Fire    Flying      False   78
# 12     9    BlastoiseMega Blastoise     Water       NaN      False   79
# 19    15      BeedrillMega Beedrill       Bug    Poison      False   65
# 23    18        PidgeotMega Pidgeot    Normal    Flying      False   83
# 71    65      AlakazamMega Alakazam   Psychic       NaN      False   55
# 87    80        SlowbroMega Slowbro     Water   Psychic      False   95
# 102   94          GengarMega Gengar     Ghost    Poison      False   60
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN      False  105
# 137  127          PinsirMega Pinsir       Bug    Flying      False   65
# 141  130      GyaradosMega Gyarados     Water      Dark      False   95
# ...

# %% [markdown]
# Unfilering the name except Mega

# %%
f_txt.loc[~f_txt['Name'].str.contains('Mega ')]
# Out:
#        #                 Name   Type 1  Type 2  Legendary   HP  Attack  \
# 0      1            Bulbasaur    Grass  Poison      False   45      49
# 1      2              Ivysaur    Grass  Poison      False   60      62
# 2      3             Venusaur    Grass  Poison      False   80      82
# 4      4           Charmander     Fire     NaN      False   39      52
# 5      5           Charmeleon     Fire     NaN      False   58      64
# ..   ...                  ...      ...     ...        ...  ...     ...
# 794  718     Zygarde50% Forme   Dragon  Ground       True  108     100
# 795  719              Diancie     Rock   Fairy       True   50     100
# 797  720  HoopaHoopa Confined  Psychic   Ghost       True   80     110
# 798  720   HoopaHoopa Unbound  Psychic    Dark       True   80     160
# 799  721            Volcanion     Fire   Water       True   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

# %%
f_txt.loc[f_txt['Type 1'].str.contains('Fire|Grass',flags=re.I,regex=True)]
# Out:
#        #                   Name Type 1  Type 2  Legendary   HP  Attack  \
# 0      1              Bulbasaur  Grass  Poison      False   45      49
# 1      2                Ivysaur  Grass  Poison      False   60      62
# 2      3               Venusaur  Grass  Poison      False   80      82
# 3      3  VenusaurMega Venusaur  Grass  Poison      False   80     100
# 4      4             Charmander   Fire     NaN      False   39      52
# ..   ...                    ...    ...     ...        ...  ...     ...
# 735  667                 Litleo   Fire  Normal      False   62      50
# 736  668                 Pyroar   Fire  Normal      False   86      68
# 740  672                 Skiddo  Grass     NaN      False   66      65
# 741  673                 Gogoat  Grass     NaN      False  123     100
# 799  721              Volcanion   Fire   Water       True   80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
f_txt.loc[f_txt['Name'].str.contains('pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                     Name    Type 1    Type 2  Legendary   HP  Attack  \
# 13    10                 Caterpie       Bug       NaN      False   45      30
# 20    16                   Pidgey    Normal    Flying      False   40      45
# 21    17                Pidgeotto    Normal    Flying      False   63      60
# 22    18                  Pidgeot    Normal    Flying      False   83      80
# 23    18      PidgeotMega Pidgeot    Normal    Flying      False   83      80
# 30    25                  Pikachu  Electric       NaN      False   35      55
# 42    37                   Vulpix      Fire       NaN      False   38      41
# 76    70               Weepinbell     Grass    Poison      False   65      90
# 84    78                 Rapidash      Fire       NaN      False   65     100
# 136  127                   Pinsir       Bug       NaN      False   65     125
# 137  127        PinsirMega Pinsir       Bug    Flying      False   65     155
# ...

# %%
f_txt.loc[f_txt['Name'].str.contains('^pi[a-z]*',flags=re.I,regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Legendary   HP  Attack  \
# 20    16               Pidgey    Normal    Flying      False   40      45
# 21    17            Pidgeotto    Normal    Flying      False   63      60
# 22    18              Pidgeot    Normal    Flying      False   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying      False   83      80
# 30    25              Pikachu  Electric       NaN      False   35      55
# 136  127               Pinsir       Bug       NaN      False   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying      False   65     155
# 186  172                Pichu  Electric       NaN      False   20      40
# 219  204               Pineco       Bug       NaN      False   50      65
# 239  221            Piloswine       Ice    Ground      False  100     100
# 438  393               Piplup     Water       NaN      False   53      51
# 558  499              Pignite      Fire  Fighting      False   90      93
# ...

# %% [markdown]
# Conditional changes in data

# %%
f_txt.loc[f_txt['Type 1'] == 'Fire', 'Type 1'] = 'Flamer'
f_txt
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander   Flamer     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion   Flamer   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
f_txt.loc[f_txt['Type 1'] == 'Flamer', 'Type 1'] = 'Fire'
f_txt
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN      False  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
f_txt.loc[f_txt['Type 1'] == 'Fire', 'Legendary'] = True
f_txt
# Out:
#        #                   Name   Type 1  Type 2  Legendary  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison      False  45      49
# 1      2                Ivysaur    Grass  Poison      False  60      62
# 2      3               Venusaur    Grass  Poison      False  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison      False  80     100
# 4      4             Charmander     Fire     NaN       True  39      52
# ..   ...                    ...      ...     ...        ...  ..     ...
# 795  719                Diancie     Rock   Fairy       True  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       True  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       True  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       True  80     160
# 799  721              Volcanion     Fire   Water       True  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Aggregate statistics(Groupby)

# %%
df = pd.read_csv('fled.csv')

# %%
df.groupby(['Type 1']).mean().sort_values('HP', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~/.local/lib/python3.11/site-packages/pandas/core/groupby/ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958 ngroups = self.ngroups
# ...

# %%
df.groupby(['Type 1']).sum()
# Out:
#           Unnamed: 0      #  \
# Type 1
# Bug            25397  23080
# Dark           15729  14302
# Dragon         16699  15180
# Electric       17626  15994
# Fairy           8407   7642
# Fighting       10812   9824
# Fire           18769  17025
# Flying          2986   2711
# Ghost          17161  15568
# Grass          26629  24141
# Ground         12554  11401
# Ice            11176  10165
# Normal         34455  31279
# Poison          7792   7050
# Psychic        23946  21706
# Rock           19001  17280
# Steel          13130  11957
# Water          37331  33946
#
#                                                        Name  \
# Type 1
# Bug       CaterpieMetapodButterfreeWeedleKakunaBeedrillB...
# Dark      UmbreonMurkrowSneaselHoundourHoundoomHoundoomM...
# Dragon    DratiniDragonairDragoniteAltariaAltariaMega Al...
# Electric  PikachuRaichuMagnemiteMagnetonVoltorbElectrode...
# Fairy     ClefairyClefableCleffaTogepiTogeticSnubbullGra...
# ...
